# %%
from langchain_ollama import ChatOllama
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_core.output_parsers import StrOutputParser

# %%
llm = ChatOllama(
    model='llama3.2:latest'
)

# %%
parser = StrOutputParser()

# %%
chain = llm | parser

# %%
result = chain.invoke("hello")

# %%
result
# Out:
# 'Hello! How can I assist you today?'

# %%
class LLMState(TypedDict):

    question : str 
    answer : str

# %%
def printer(state : LLMState) -> LLMState: 

    question = state['question']

    answer = chain.invoke(question)

    state['answer'] = answer

    return state

# %%
graph = StateGraph(LLMState)

graph.add_node('printer',printer)

graph.add_edge(START,'printer')
graph.add_edge('printer',END)

workflow = graph.compile()

# %%
result = workflow.invoke({'question':"Explain about Artificial Intelligence"})

# %%
result
# Out:
# {'question': 'Explain about Artificial Intelligence',
#  'answer': "Artificial Intelligence (AI) refers to the development of computer systems that can perform tasks that typically require human intelligence, such as learning, problem-solving, and decision-making. The goal of AI is to create machines that can think and act like humans, making it easier for people to interact with technology.\n\nTypes of Artificial Intelligence:\n\n1. **Narrow or Weak AI**: This type of AI is designed to perform a specific task, such as facial recognition, language translation, or playing chess. Narrow AI systems are trained on a particular dataset and can improve over time through machine learning algorithms.\n2. **General or Strong AI**: This type of AI aims to create machines that can perform any intellectual task that humans can, including reasoning, problem-solving, and learning. General AI is still a theoretical concept and has yet to be achieved in practice.\n3. **Superintelligence**: This term refers to AI systems that are significantly more intelligent than the best human minds. Superintelligent AI could potentially solve complex problems, such as climate change or world hunger.\n\nTechniques used in Artificial Intelligence:\n\n1. **Machine Learning (ML)**: ML involves training algorithms on data to improve their performance over time.\n2. **Deep Learning (DL)**: DL is a subset of ML that uses neural networks with multiple layers to learn complex patterns in data.\n3. **Natural Language Processing (NLP)**: NLP enables computers to understand, interpret, and generate human language.\n4. **Computer Vision**: Computer vision allows machines to interpret and make decisions based on visual information.\n\nApplications of Artificial Intelligence:\n\n1. **Virtual Assistants**: AI-powered virtual assistants, such as Siri, Alexa, or Google Assistant, can perform tasks like scheduling appointments or sending messages.\n2. **Image Recognition**: AI-powered image recognition systems can identify objects, people, and patterns in images.\n3. **Predictive Maintenance**: AI-powered predictive maintenance systems can analyze sensor data to predict equipment failures and schedule maintenance.\n4. **Autonomous Vehicles**: AI-powered autonomous vehicles use computer vision, machine learning, and sensor data to navigate roads and make decisions.\n\nBenefits of Artificial Intelligence:\n\n1. **Improved Efficiency**: AI can automate repetitive tasks, freeing up time for more strategic activities.\n2. **Enhanced Decision-Making**: AI can analyze vast amounts of data, providing insights that humans may miss.\n3. **Personalization**: AI-powered systems can tailor experiences to individual preferences and needs.\n4. **Increased Productivity**: AI can help companies automate processes, leading to increased productivity and competitiveness.\n\nHowever, AI also raises concerns about:\n\n1. **Job Displacement**: Automation could displace jobs, particularly in sectors where tasks are repetitive or routine.\n2. **Bias and Discrimination**: AI systems can perpetuate biases present in the data used to train them.\n3. **Cybersecurity Risks**: AI-powered systems can be vulnerable to cyber attacks, potentially leading to data breaches or other security threats.\n\nAs AI continues to evolve, it's essential to address these concerns and develop responsible AI practices that prioritize human well-being and dignity."}

# %%
from IPython.display import Image
Image(workflow.get_graph().draw_mermaid_png())
